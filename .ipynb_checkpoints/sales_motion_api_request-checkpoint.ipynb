# %%
### import des librairies

import os
from dotenv import load_dotenv
import pandas as pd
import requests

# %%
### construction de la requête api

url = "https://api.salesmotion.io/v1/usage"

# récupération de notre api_key dans .env

load_dotenv()
api_key = os.getenv("SALESMOTION_API_KEY")

header = {"Authorization": f"Bearer {api_key}"}

response = requests.get(url, headers=header)

# vérification du code status, si 200, enregistreement de la data,
# sinon affichage du message d'erreur si différent de 200 (success)

if response.status_code == 200:
    data = response.json()
    print("Data has been collected")
else:
    print(f"Erreur {response.status_code} : {response.text}")
# Out:
# Data has been collected

# %%
data
# Out:
# {'data': {'window': 'monthly',
#   'from': '2026-07-26T07:50:17.906Z',
#   'to': '2026-08-25T07:50:17.906Z',
#   'quota': {'limit': 100,
#    'used': 0,
#    'remaining': 100,
#    'resetsAt': '2026-09-24T07:50:18.090Z'},
#   'totals': {'requests': 0, 'successful': 0, 'failed': 0}},
#  'meta': {'requestId': 'f4382e4e-f454-401b-bd45-1d2e87054ec5',
#   'apiVersion': 'v1',
#   'timestamp': '2026-08-25T07:50:18.091Z'}}

# %%
response.text
# Out:
# '{"data":{"window":"monthly","from":"2026-07-26T07:50:17.906Z","to":"2026-08-25T07:50:17.906Z","quota":{"limit":100,"used":0,"remaining":100,"resetsAt":"2026-09-24T07:50:18.090Z"},"totals":{"requests":0,"successful":0,"failed":0}},"meta":{"requestId":"f4382e4e-f454-401b-bd45-1d2e87054ec5","apiVersion":"v1","timestamp":"2026-08-25T07:50:18.091Z"}}'
